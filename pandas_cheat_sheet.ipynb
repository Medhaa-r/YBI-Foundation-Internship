# %% [markdown]
# <a href="https://colab.research.google.com/github/Medhaa-r/YBI-Foundation-Internship/blob/main/pandas_cheat_sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# PANDAS CHEAT SHEET

# %%
df = pd.DataFrame(
{"a" : [4, 5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = [1, 2, 3])

# %%
df2 = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index=[1, 2, 3],
columns=['a', 'b', 'c'])

# %%
df3 = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = pd.MultiIndex.from_tuples(
[('d', 1), ('d', 2),
('e', 2)], names=['n', 'v']))

# %%
pd.melt(df)
# Out:
#   variable  value
# 0        a      4
# 1        a      5
# 2        a      6
# 3        b      7
# 4        b      8
# 5        b      9
# 6        c     10
# 7        c     11
# 8        c     12

# %%
pd.concat([df,df2])
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
pd.concat([df,df2], axis=1)
# Out:
#    a  b   c  a  b   c
# 1  4  7  10  4  7  10
# 2  5  8  11  5  8  11
# 3  6  9  12  6  9  12

# %%
df.sort_values('a')
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df.sort_values('a', ascending=False)
# Out:
#    a  b   c
# 3  6  9  12
# 2  5  8  11
# 1  4  7  10

# %%
df.sort_index()
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df.rename(columns = {'a':'year'})
# Out:
#    year  b   c
# 1     4  7  10
# 2     5  8  11
# 3     6  9  12

# %%
df.drop_duplicates()
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df.sample(n=2)
# Out:
#    a  b   c
# 2  5  8  11
# 1  4  7  10

# %%
df.head(1)
# Out:
#    a  b   c
# 1  4  7  10

# %%
df.tail(2)
# Out:
#    a  b   c
# 2  5  8  11
# 3  6  9  12

# %%
df2.iloc[1:3]
# Out:
#    a  b   c
# 2  5  8  11
# 3  6  9  12

# %%
df2.iloc[:, [0, 1]]
# Out:
#    a  b
# 1  4  7
# 2  5  8
# 3  6  9

# %%
df['a'].value_counts()
# Out:
# 4    1
# 5    1
# 6    1
# Name: a, dtype: int64

# %%
len(df)
# Out:
# 3

# %%
df.shape
# Out:
# (3, 3)

# %%
df['b'].nunique()
# Out:
# 3

# %%
df.describe()
# Out:
#          a    b     c
# count  3.0  3.0   3.0
# mean   5.0  8.0  11.0
# std    1.0  1.0   1.0
# min    4.0  7.0  10.0
# 25%    4.5  7.5  10.5
# 50%    5.0  8.0  11.0
# 75%    5.5  8.5  11.5
# max    6.0  9.0  12.0

# %%
pd.merge(df, df2,
how='left', on='a')
# Out:
#    a  b_x  c_x  b_y  c_y
# 0  4    7   10    7   10
# 1  5    8   11    8   11
# 2  6    9   12    9   12

# %%
pd.merge(df, df2,
how='right', on='b')
# Out:
#    a_x  b  c_x  a_y  c_y
# 0    4  7   10    4   10
# 1    5  8   11    5   11
# 2    6  9   12    6   12

# %%
pd.merge(df, df2,
how='inner', on='a')
# Out:
#    a  b_x  c_x  b_y  c_y
# 0  4    7   10    7   10
# 1  5    8   11    8   11
# 2  6    9   12    9   12

# %%
pd.merge(df, df2,
how='outer', on='c')
# Out:
#    a_x  b_x   c  a_y  b_y
# 0    4    7  10    4    7
# 1    5    8  11    5    8
# 2    6    9  12    6    9

# %%
pd.merge(df, df2)
# Out:
#    a  b   c
# 0  4  7  10
# 1  5  8  11
# 2  6  9  12

# %%
pd.merge(df, df2, how='outer')
# Out:
#    a  b   c
# 0  4  7  10
# 1  5  8  11
# 2  6  9  12

# %%
df.assign(Area=lambda df: df.a*df.b)
# Out:
#    a  b   c  Area
# 1  4  7  10    28
# 2  5  8  11    40
# 3  6  9  12    54

# %%
df['product'] = df.a*df.b*df.c

# %%
pd.qcut(df.a, 2, labels=False)
# Out:
# 1    0
# 2    0
# 3    1
# Name: a, dtype: int64

# %%
df.dropna()
# Out:
#    a  b   c  product
# 1  4  7  10      280
# 2  5  8  11      440
# 3  6  9  12      648

# %%
df.fillna(333)
# Out:
#    a  b   c  product
# 1  4  7  10      280
# 2  5  8  11      440
# 3  6  9  12      648

# %%
df.plot.hist()

# %%
df.plot.scatter(x='a',y='c')
